# %%
from selenium import webdriver 
from selenium.webdriver.common.keys import Keys

from bs4 import BeautifulSoup
import requests
import pandas as pd
from tqdm import tqdm
import time
from lxml import etree
import re
from langdetect import detect

# %%
browser=webdriver.Chrome(r"C:\Users\hayat er-rabbany\Desktop\drivechrom\chromedriver.exe")

browser.get("https://www.linkedin.com/in/bouchra-er-rabbany/detail/recent-activity/")
# Out:
# <ipython-input-142-cbded956399f>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser=webdriver.Chrome(r"C:\Users\hayat er-rabbany\Desktop\drivechrom\chromedriver.exe")

# %%
links_listcvnew=[]
current = 1
list_=browser.find_elements_by_class_name("artdeco-list__item ")
for i in list_:
    try:
        a = i.find_element_by_tag_name('a')
        links_listcvnew.append(a.get_property('href'))
        current +=1
    except:
        pass
# Out:
# <ipython-input-144-58b6200df859>:3: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   list_=browser.find_elements_by_class_name("artdeco-list__item ")

# %%
len(links_listcvnew)
# Out:
# 2422

# %%
links_list =links_listcvnew

# %%
del links_list[0:8]

# %%
len(links_list)
# Out:
# 1903

# %%
cv_list=[]
for d in tqdm(links_list):
    browser.get(d)
    SCROLL_PAUSE_TIME=5

    last_height=browser.execute_script('return document.body.scrolHeight')

    for i in range(3):
        browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    
        time.sleep(SCROLL_PAUSE_TIME)
    
        new_height=browser.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height
            
    src = browser.page_source
        
    soup = BeautifulSoup(src, "html.parser")
        
    
    key1='Experience'
    key2='Education'
    key3='Skills'
    
     
    experience=''
    education=''
    name=''
    location=''
    skills =''
    
    name = soup.find("h1", {"class":"text-heading-xlarge"}).text
    location=soup.find("span",{"class":"text-body-small"}).text
    

    u=soup.find_all()
    lang=detect(soup.text)

    if lang == 'en':
        
        for j in u:
            p=j
            if p.name == 'h2':
            #************************************************************************************key1
                if key1 in p.text:
                    p=p.find_next()
                    h1=''
                    while p.name != 'li':
                        p=p.find_next()
                    while True:
                        h1=h1+p.text
                        p=p.find_next()
                        if p.name == 'li':
                            h1=h1+';'
                        if p.name == 'div':
                            break
                        else:
                            while p.name != 'li':
                                p=p.find_next()
                
              
                    experience=experience+h1
               #************************************************************************************key2 
                if key2 in p.text:
                    p=p.find_next()
                    h2=''
                    while p.name != 'li':
                        p=p.find_next()
                    while True:
                        h2=h2+p.text
                        p=p.find_next()
                        if p.name == 'li':
                            h2=h2+';'
                        if p.name == 'div':
                            break
                        else:
                            while p.name != 'li':
                                p=p.find_next()
                    p=p.find_next()
                
                    while p.name != 'li':
                        p=p.find_next()
                    while True:
                        h2=h2+p.text
                        p=p.find_next()
                        if p.name == 'li':
                            h2=h2+';'
                        if p.name == 'div':
                            break
                        else:
                            while p.name != 'li':
                                p=p.find_next()
                    p=p.find_next()
                
                    while p.name != 'li':
                        p=p.find_next()
                    while True:
                        h2=h2+p.text
                        p=p.find_next()
                        if p.name == 'li':
                            h2=h2+';'
                        if p.name == 'div':
                            break
                        else:
                            while p.name != 'li':
                                p=p.find_next()
                    education=education+h2
                if key3 in p.text:
                    p=p.find_next()
                    h2=''
                    while p.name != 'li':
                        p=p.find_next()
                    while True:
                        h2=h2+p.text
                        p=p.find_next()
                        if p.name == 'li':
                            h2=h2+';'
                        if p.name == 'div':
                            break
                        else:
                            while p.name != 'li':
                                p=p.find_next()
                    p=p.find_next()
              
                    while p.name != 'li':
                        p=p.find_next()
                    while True:
                        h2=h2+p.text
                        p=p.find_next()
                        if p.name == 'li':
                            h2=h2+';'
                        if p.name == 'div':
                            break
                        else:
                            while p.name != 'li':
                                p=p.find_next()
                    p=p.find_next()
                
                    while p.name != 'li':
                        p=p.find_next()
                    while True:
                        h2=h2+ " "+p.text
                        p=p.find_next()
                        if p.name == 'li':
                            h2=h2+' ;'
                        if p.name == 'div':
                            break
                        else:
                            while p.name != 'li':
                                p=p.find_next()
                    skills=skills+h2
                
        if (experience != '' and education !='') :
                    
            data={
                                     'name':name,
                                        'location':location,
                                          'experience':experience,
                                           'skills':skills,
                                          'education':education,
                                          'link':d}
            cv_list.append(data)
# Out:
#   1%|▉                                                                            | 23/1861 [09:27<12:35:11, 24.65s/it]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-150-a3305302ecc1> in <module>
#      32     skills =''
#      33
# ---> 34     name = soup.find("h1", {"class":"text-heading-xlarge"}).text
#      35     location=soup.find("span",{"class":"text-body-small"}).text
#      36
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
len(cv_list)
# Out:
# 0

# %%
 cv_list3 = cv_list3 +cv_list

# %%
len(cv_list3)
# Out:
# 81

# %%
data =pd.DataFrame(cv_list3)

# %%
data
# Out:
#                       name                                           location  \
# 0     Sundaresan Murugesan        \n      Coimbatore, Tamil Nadu, India\n
# 1           Michael Cassel   \n      Sydney, New South Wales, Australia\n
# 2            Stephen Birch         \n      Officer, Victoria, Australia\n
# 3                  Maria P     \n      Corning, New York, United States\n
# 4   Jorge Humberto Martins           \n      Coimbra, Coimbra, Portugal\n
# ..                     ...                                                ...
# 59       Marvin Ruthenberg                  \n      Greater Tucson Area\n
# 60       Rebecca Genteline         \n      Washington DC-Baltimore Area\n
# 61               Vicky Sun                            \n      Singapore\n
# 62    Nicole Kramer-Skjeie       \n      Fort McMurray, Alberta, Canada\n
# 63          Jeffrey Earles  \n      Lakeville, Minnesota, United States\n
#
#                                            experience skills  \
# 0
# ...

# %%
list_fin = list_fin +cv_list

# %%
len(list_fin)
# Out:
# 591

# %%
cv_list360
# Out:
# [{'name': 'Rizal Razuwan',
#   'location': '\n      Cheras, Selangor, Malaysia\n    ',
#   'experience': '\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\nResearch Officer Research Officer \n\n \n\nSystem Engineering and Energy Lab (SEELAB) · Part-timeSystem Engineering and Energy Lab (SEELAB) · Part-time\n\n\n2016 - Present · 5 yrs 11 mos2016 - Present · 5 yrs 11 mos\n\n\n\n\n\n \n\n \n\n',
#   'skills': '\n\n\n\n\n\n\n\n\n\n\n\nEmbedded SystemsEmbedded Systems\n\n \n· 2· 2\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nMolecular DynamicsMolecular Dynamics\n\n \n· 3· 3\n\n\n\n\n\n\n \n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\nMachine LearningMachine Learning\n\n \n· 2· 2\n\n\n\n\n\n\n \n\n\n\n\n\n',
# ...

# %%
cv_list78
# Out:
# [{'name': 'Dikshant Gupta',
#   'location': '\n      Saarbrücken, Saarland, Germany\n    ',
#   'experience': '\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\nResearch AssistantResearch Assistant\n\n \n\nDeutsches Forschungszentrum für Künstliche Intelligenz (DFKI) · Part-timeDeutsches Forschungszentrum für Künstliche Intelligenz (DFKI) · Part-time\n\n\nMay 2020 - Present · 1 yr 7 mosMay 2020 - Present · 1 yr 7 mos\n\n\nSaarbrücken, SaarlandSaarbrücken, Saarland\n\n\n\n\n \n\n \n\n',
# ...

# %%
import pandas as pd
df=pd.DataFrame(list_fin)

# %%
df
# Out:
#                       name                                           location  \
# 0            Eyal Michaeli                               \n      Israël\n
# 1         Pradeep Palreddy   \n      Cary, Caroline du Nord, États-Unis\n
# 2                   Jun Gu                      \n      Shanghai, Chine\n
# 3       Shuang (Sherry) Yu       \n      Melbourne, Victoria, Australie\n
# 4         Oussama ZOGHLAMI     \n      Montrouge, Île-de-France, France\n
# ..                     ...                                                ...
# 586     Eduardo Muñoz Sala                 \n      Madrid et périphérie\n
# 587  Rafael Simões Miranda            \n      Berlin, Berlin, Allemagne\n
# 588         Priyank Pathak     \n      Bangalore Urban, Karnataka, Inde\n
# 589          Alex Andrascu  \n      Milton Keynes, Angleterre, Royaume-Uni...
# 590          Borja Carrero  \n      Düsseldorf, Rhénanie du Nord-Westphali...
#
#     experience skills education  \
# 0
# 1
# 2
# 3
# 4
# ...

# %%
import pandas as pd
import string
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk import WordNetLemmatizer

# %% [markdown]
# # Conversion en minuscule

# %%
ls=dict()
for i in df['name']:
    ls['name']=[]
for i in df['name']:
    ls['name'].append(i.lower())
df['name_lower']=ls['name']

# %%
ls=dict()
for i in df['location']:
    ls['location']=[]
for i in df['location']:
    ls['location'].append(i.lower())
df['location_lower']=ls['location']

# %%
ls=dict()
for i in df['experience']:
    ls['experience']=[]
for i in df['experience']:
    ls['experience'].append(i.lower())
df['experience_lower']=ls['experience']

# %%
ls=dict()
for i in df['skills']:
    ls['skills']=[]
for i in df['skills']:
    ls['skills'].append(i.lower())
df['skills_lower']=ls['skills']

# %%
ls=dict()
for i in df['education']:
    ls['education']=[]
for i in df['education']:
    ls['education'].append(i.lower())
df['education_lower']=ls['education']

# %% [markdown]
#  # Eliminer la ponctuation

# %%
ls=dict()
for i in df['name_lower']:
    ls['name_txt']=[]
for i in df['name_lower']:
    ls['name_txt'].append(i.translate(str.maketrans('','',string.punctuation)))
df['name_ponctuation']=ls['name_txt']

# %%
#location	experience	skills	education	
ls=dict()
for i in df['location_lower']:
    ls['location_txt']=[]
for i in df['location_lower']:
    ls['location_txt'].append(i.translate(str.maketrans('','',string.punctuation)))
df['location_ponctuation']=ls['location_txt']

# %%
ls=dict()
for i in df['experience_lower']:
    ls['experience_txt']=[]
for i in df['experience_lower']:
    ls['experience_txt'].append(i.translate(str.maketrans('','',string.punctuation)))
df['experience_ponctuation']=ls['experience_txt']

# %%
ls=dict()
for i in df['skills_lower']:
    ls['skills_txt']=[]
for i in df['skills_lower']:
    ls['skills_txt'].append(i.translate(str.maketrans('','',string.punctuation)))
df['skills_ponctuation']=ls['skills_txt']

# %%
ls=dict()
for i in df['education_lower']:
    ls['education_txt']=[]
for i in df['education_lower']:
    ls['education_txt'].append(i.translate(str.maketrans('','',string.punctuation)))
df['education_ponctuation']=ls['education_txt']

# %% [markdown]
# # Tokenization par mot

# %%
df
# Out:
#                       name                                           location  \
# 0            Eyal Michaeli                               \n      Israël\n
# 1         Pradeep Palreddy   \n      Cary, Caroline du Nord, États-Unis\n
# 2                   Jun Gu                      \n      Shanghai, Chine\n
# 3       Shuang (Sherry) Yu       \n      Melbourne, Victoria, Australie\n
# 4         Oussama ZOGHLAMI     \n      Montrouge, Île-de-France, France\n
# ..                     ...                                                ...
# 586     Eduardo Muñoz Sala                 \n      Madrid et périphérie\n
# 587  Rafael Simões Miranda            \n      Berlin, Berlin, Allemagne\n
# 588         Priyank Pathak     \n      Bangalore Urban, Karnataka, Inde\n
# 589          Alex Andrascu  \n      Milton Keynes, Angleterre, Royaume-Uni...
# 590          Borja Carrero  \n      Düsseldorf, Rhénanie du Nord-Westphali...
#
#     experience skills education  \
# 0
# 1
# 2
# 3
# 4
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-97-cccd69040b2c> in <module>
#       3     ls['name_txt']=[]
#       4 for i in df['name_ponctuation']:
# ----> 5     ls['name_txt'].append(word_tokenize(i))
#       6 df['name_tokenized']=ls['name_txt']
#
# ~\anaconda3\lib\site-packages\nltk\tokenize\__init__.py in word_tokenize(text, language, preserve_line)
#     128     :type preserve_line: bool
#     129     """
# --> 130     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     131     return [
#     132         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#
# ~\anaconda3\lib\site-packages\nltk\tokenize\__init__.py in sent_tokenize(text, language)
#     105     :param language: the model name in the Punkt corpus
#     106     """
# ...

# %%
ls=dict()
for i in df['name_ponctuation']:
    ls['name_txt']=[]
for i in df['name_ponctuation']:
    ls['name_txt'].append(word_tokenize(i))
df['name_tokenized']=ls['name_txt']

# %%
ls=dict()
for i in df['name_ponctuation']:
    ls['name_txt']=[]
for i in df['name_ponctuation']:
    ls['name_txt'].append(word_tokenize(i))
df['name_tokenized']=ls['name_txt']

# %%
ls=dict()
for i in df['name_ponctuation']:
    ls['name_txt']=[]
for i in df['name_ponctuation']:
    ls['name_txt'].append(word_tokenize(i))
df['name_tokenized']=ls['name_txt']

# %%
df
# Out:
#                       name                                           location  \
# 0            Eyal Michaeli                               \n      Israël\n
# 1         Pradeep Palreddy   \n      Cary, Caroline du Nord, États-Unis\n
# 2                   Jun Gu                      \n      Shanghai, Chine\n
# 3       Shuang (Sherry) Yu       \n      Melbourne, Victoria, Australie\n
# 4         Oussama ZOGHLAMI     \n      Montrouge, Île-de-France, France\n
# ..                     ...                                                ...
# 586     Eduardo Muñoz Sala                 \n      Madrid et périphérie\n
# 587  Rafael Simões Miranda            \n      Berlin, Berlin, Allemagne\n
# 588         Priyank Pathak     \n      Bangalore Urban, Karnataka, Inde\n
# 589          Alex Andrascu  \n      Milton Keynes, Angleterre, Royaume-Uni...
# 590          Borja Carrero  \n      Düsseldorf, Rhénanie du Nord-Westphali...
#
#     experience skills education  \
# 0
# 1
# 2
# 3
# 4
# ...

# %%
cv_list3.to_csv(r"C:\Users\hayat er-rabbany\Desktop\bigdataprop\Newcv.csv",index=False)

# %%
del cv_list3['link']
